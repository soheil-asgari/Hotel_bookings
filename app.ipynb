# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"./data/Hotel Bookings.csv")

df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# We draw a graph to better understand the data distribution

# %%
df.hist(bins=40, figsize=(20, 14))
plt.show()

# %% [markdown]
# Here we see the number of empty values ​​in each column

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %% [markdown]
# And for the company column, because there are many data without values, we delete it

# %%
df = df.drop("company", axis=1)

# %% [markdown]
# We use pandas to fill in the non values

# %%
df["children"].fillna(method="pad", inplace=True)
df["country"].fillna(method="pad", inplace=True)
df["agent"].fillna(method="bfill", inplace=True)
# Out:
# C:\Users\sohei\AppData\Local\Temp\ipykernel_15144\4039617579.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["children"].fillna(method="pad", inplace=True)
# C:\Users\sohei\AppData\Local\Temp\ipykernel_15144\4039617579.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["country"].fillna(method="pad", inplace=True)
# C:\Users\sohei\AppData\Local\Temp\ipykernel_15144\4039617579.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["agent"].fillna(method="bfill", inplace=True)

# %% [markdown]
# Duplicate data is deleted

# %%
df = df.drop_duplicates()

# %% [markdown]
# From here on, we will call the data that we worked with the name of Hotel_bookings

# %%
Hotel_bookings = df

# %% [markdown]
# There  are  two  types  of  hotels  in  the  dataset,  which  type  of  hotels
# booked most? Plot a pie chart to show the results.

# %% [markdown]
# We check the status of reservations

# %%
Hotel_bookings["reservation_status"].unique()
# Out:
# array(['Check-Out', 'Canceled', 'No-Show'], dtype=object)

# %% [markdown]
# We can see which hotel had more requests for reservations

# %%
most_reserv = Hotel_bookings.groupby("hotel")["reservation_status"].count()
most_reserv
# Out:
# hotel
# City Hotel      53679
# Resort Hotel    34224
# Name: reservation_status, dtype: int64

# %% [markdown]
# Enter the required libraries to draw the graph

# %%
sns.set_style("white")
plt.rcParams["font.size"] = 9.0
colors = ["#9c9c9c", "#4e4e4e"]
plt.figure(figsize=(12, 8))
patches, texts, autotexts = plt.pie(
    data=Hotel_bookings,
    x=most_reserv,
    labels=most_reserv.index,
    autopct="%1.1f%%",
    colors=colors,
)
texts[0].set_fontsize(10)
plt.setp(autotexts, **{"color": "white", "weight": "bold", "fontsize": 12.5})
plt.setp(texts, **{"color": "gray", "weight": "bold", "fontsize": 10.5})
plt.title(
    "Hotels booked most",
    fontdict={"color": "#4e4e4e", "weight": "bold", "fontsize": 12.5},
    loc="left",
)
plt.show()

# %% [markdown]
# What percentage of bookings were cancelled? What type of chart
# do you suggest to show the results?

# %%
df["is_canceled"].value_counts()
# Out:
# is_canceled
# 0    63767
# 1    24136
# Name: count, dtype: int64

# %%
df.groupby("hotel")["is_canceled"].sum().reset_index()
# Out:
#           hotel  is_canceled
# 0    City Hotel        16122
# 1  Resort Hotel         8014
